# %% [markdown]
# # Linking Movie Titles in Multiple Data Tables
#
#
# ## String Matching approach

# %%
# %%bash
# #pip install fuzzywuzzy
# #pip install python-Levenshtein

# %%
from fuzzywuzzy import process
from unidecode import unidecode

# %%
import pandas as pd
from ast import literal_eval
import numpy as np
import os

def clean(row):
    '''apply on rows of a dataframe to clean up'''
    #this is because CSV conversion has converted list into string
    row['plots'] = literal_eval(row['plots'])
    try:
        row['year'] = int(row['year'])
        return row
    except:
        row['year'] = np.nan
        return row

# TODO: Set this appropriately
dropbox_dir = "C:\\Users\\sooraj.raveendra\\Dropbox\\moviemeta\\"

movieplots = pd.read_csv(dropbox_dir + 'movieplots.csv')
movieplots = movieplots.apply(clean, axis = 1)

# %%
'''
    The do_fuzzy parameter controls whether the approximate string match algorithm (Levenshtein algorithm)
    is used or not.
    
    WARNING: doing fuzzy search can take a LOT of time
'''
def create_title_map(imdb_titles, wiki_titles, year, do_fuzzy=False):
    titledict = {}
    for wiki_title in wiki_titles:
        match = next((s for s in list(imdb_titles) if s == wiki_title + " (%d)" % year), None)
        if(match is None and do_fuzzy):
            fuzzy_match, similarity_pct = process.extractOne(wiki_title + " (%d)" % year, imdb_titles)
            if(similarity_pct >= 90): # Take only the ones with high similarity
                match = fuzzy_match

        if(match is not None):
            titledict[wiki_title] = match
    
    return titledict
            
yearly_maps = {}
for year in range(2010, 2015):
    imdbdf = movieplots[movieplots.year == year]
    imdb_titles = imdbdf.title.apply(lambda x: unidecode(x))
    wikidf = pd.read_table(os.path.join(dropbox_dir, "wikipedia", "wikipedia_plots_%d.csv" % year))
    yearly_maps[year] = create_title_map(imdb_titles, wikidf.title, year, False)
# Out:
# E:\Anaconda\envs\py27\lib\site-packages\ipykernel\__main__.py:24: RuntimeWarning: Argument <type 'str'> is not an unicode object. Passing an encoded string will likely have unexpected results.

# %%
yearly_maps[2013]
# Out:
# {'11.6': '11.6 (2013)',
#  '12 Years a Slave': '12 Years a Slave (2013)',
#  '2 Guns': '2 Guns (2013)',
#  '21 & Over': '21 & Over (2013)',
#  '3 Geezers!': '3 Geezers! (2013)',
#  '42': '42 (2013)',
#  '47 Ronin': '47 Ronin (2013)',
#  '6-5=2': '6-5=2 (2013)',
#  '7 Assassins': '7 Assassins (2013)',
#  '9 Full Moons': '9 Full Moons (2013)',
#  "A Birder's Guide to Everything": "A Birder's Guide to Everything (2013)",
#  'A Farewell to Fools': 'A Farewell to Fools (2013)',
#  'A Field in England': 'A Field in England (2013)',
#  'A Good Day to Die Hard': 'A Good Day to Die Hard (2013)',
#  'A Haunted House': 'A Haunted House (2013)',
#  'A Madea Christmas': 'A Madea Christmas (2013)',
#  'A Mile from Home': 'A Mile from Home (2013)',
#  'A Moment of Love': 'A Moment of Love (2013)',
#  'A Night in Old Mexico': 'A Night in Old Mexico (2013)',
#  'A Promise': 'A Promise (2013)',
#  'A Resurrection': 'A Resurrection (2013)',
#  'A River Changes Course': 'A River Changes Course (2013)',
#  'A Spell to Ward Off the Darkness': 'A Spell to Ward Off the Darkness (2013)',
#  'A Strange Course of Events': 'A Strange Course of Events (2013)',
#  'A Stranger in Paradise': 'A Stranger in Paradise (2013)',
#  'A Teacher': 'A Teacher (2013)',
#  'A.C.O.D.': 'A.C.O.D. (2013)',
#  'Aadhalal Kadhal Seiveer': 'Aadhalal Kadhal Seiveer (2013)',
#  'Aajcha Divas Majha': 'Aajcha Divas Majha (2013)',
#  'Aatma': 'Aatma (2013)',
#  'Ada Apa Dengan Rina': 'Ada Apa Dengan Rina (2013)',
#  'Adieu Paris': 'Adieu Paris (2013)',
#  'Admission': 'Admission (2013)',
#  'Afflicted': 'Afflicted (2013)',
#  'After Earth': 'After Earth (2013)',
#  'After Tiller': 'After Tiller (2013)',
#  'After the Dark': 'After the Dark (2013)',
#  'Ai Weiwei: The Fake Case': 'Ai Weiwei: The Fake Case (2013)',
#  'Ainthu Ainthu Ainthu': 'Ainthu Ainthu Ainthu (2013)',
#  'Alan Partridge: Alpha Papa': 'Alan Partridge: Alpha Papa (2013)',
#  "Aleksandr's Price": "Aleksandr's Price (2013)",
#  'Alex Pandian': 'Alex Pandian (2013)',
#  'Algonquin': 'Algonquin (2013)',
#  "All Hallows' Eve": "All Hallows' Eve (2013)",
#  'All Is Bright': 'All Is Bright (2013)',
#  'All Is Lost': 'All Is Lost (2013)',
#  'All in All Azhagu Raja': 'All in All Azhagu Raja (2013)',
#  'All the Wrong Reasons': 'All the Wrong Reasons (2013)',
#  'Almost Human': 'Almost Human (2013)',
#  'Alone Yet Not Alone': 'Alone Yet Not Alone (2013)',
#  'Alt': 'Alt (2013)',
#  'Ambushed': 'Ambushed (2013)',
#  'American Arab': 'American Arab (2013)',
#  'American Federale': 'American Federale (2013)',
#  'American Hustle': 'American Hustle (2013)',
#  'American Milkshake': 'American Milkshake (2013)',
#  'American Revolutionary: The Evolution of Grace Lee Boggs': 'American Revolutionary: The Evolution of Grace Lee Boggs (2013)',
#  'American Vagabond': 'American Vagabond (2013)',
#  'Ami Aar Amar Girlfriends': 'Ami Aar Amar Girlfriends (2013)',
#  'Among the Dust of Thieves': 'Among the Dust of Thieves (2013)',
#  'An Obsolete Altar': 'An Obsolete Altar (2013)',
#  'Anchorman 2: The Legend Continues': 'Anchorman 2: The Legend Continues (2013)',
#  'Angel Warriors': 'Angel Warriors (2013)',
#  'Angels Sing': 'Angels Sing (2013)',
#  'Anina': 'Anina (2013)',
#  'Annayum Rasoolum': 'Annayum Rasoolum (2013)',
#  'Annum Innum Ennum': 'Annum Innum Ennum (2013)',
#  'Another Me': 'Another Me (2013)',
#  'App': 'App (2013)',
#  'Approaching Midnight': 'Approaching Midnight (2013)',
#  'Are You Here': 'Are You Here (2013)',
#  'Around the Block': 'Around the Block (2013)',
#  'Aroused': 'Aroused (2013)',
#  'Arrambam': 'Arrambam (2013)',
#  'Ashchorjyo Prodeep': 'Ashchorjyo Prodeep (2013)',
#  'Asphalt Watches': 'Asphalt Watches (2013)',
#  'Ass Backwards': 'Ass Backwards (2013)',
#  'Attila Marcel': 'Attila Marcel (2013)',
#  'August: Osage County': 'August: Osage County (2013)',
#  'Austenland': 'Austenland (2013)',
#  'Auto Raja': 'Auto Raja (2013)',
#  'Baadshah': 'Baadshah (2013)',
#  'Babysitter Massacre': 'Babysitter Massacre (2013)',
#  'Bad Milo!': 'Bad Milo! (2013)',
#  'Bad Words': 'Bad Words (2013)',
#  'Baga Beach': 'Baga Beach (2013)',
#  'Baggage Claim': 'Baggage Claim (2013)',
#  'Bajatey Raho': 'Bajatey Raho (2013)',
#  'Balupu': 'Balupu (2013)',
#  'Bandook': 'Bandook (2013)',
#  'Banshee Chapter': 'Banshee Chapter (2013)',
#  "Baseball's Last Hero: 21 Clemente Stories": "Baseball's Last Hero: 21 Clemente Stories (2013)",
#  'Bastardo': 'Bastardo (2013)',
#  'Bath Salt Zombies': 'Bath Salt Zombies (2013)',
#  'Battle of the Damned': 'Battle of the Damned (2013)',
#  'Battle of the Year': 'Battle of the Year (2013)',
#  'Beautiful Creatures': 'Beautiful Creatures (2013)',
#  'Before Midnight': 'Before Midnight (2013)',
#  'Belle': 'Belle (2013)',
#  'Bends': 'Bends (2013)',
#  'Beneath the Harvest Sky': 'Beneath the Harvest Sky (2013)',
#  'Besharam': 'Besharam (2013)',
#  'Best Kept Secret': 'Best Kept Secret (2013)',
#  'Beyond Beauty: Taiwan from Above': 'Beyond Beauty: Taiwan from Above (2013)',
#  'Beyond the Farthest Star': 'Beyond the Farthest Star (2013)',
#  'Bhajarangi': 'Bhajarangi (2013)',
#  'Big Bad Wolves': 'Big Bad Wolves (2013)',
#  'Big Sur': 'Big Sur (2013)',
#  'Billy Club': 'Billy Club (2013)',
#  'Biriyani': 'Biriyani (2013)',
#  'Black Nativity': 'Black Nativity (2013)',
#  'Blackfish': 'Blackfish (2013)',
#  'Blinder': 'Blinder (2013)',
#  'Blood Punch': 'Blood Punch (2013)',
#  'Blood of Redemption': 'Blood of Redemption (2013)',
#  'Bloody Isshq': 'Bloody Isshq (2013)',
#  'Blue Jasmine': 'Blue Jasmine (2013)',
#  'Bridegroom': 'Bridegroom (2013)',
#  'Bringing Tibet Home': 'Bringing Tibet Home (2013)',
#  'Broken City': 'Broken City (2013)',
#  "Bromance: My Brother's Romance": "Bromance: My Brother's Romance (2013)",
#  'Bullett Raja': 'Bullett Raja (2013)',
#  'Butter Lamp': 'Butter Lamp (2013)',
#  'Butter on the Latch': 'Butter on the Latch (2013)',
#  'C.O.G.': 'C.O.G. (2013)',
#  'C/O Sir': 'C/O Sir (2013)',
#  'CBGB': 'CBGB (2013)',
#  'CM101MMXI Fundamentals': 'CM101MMXI Fundamentals (2013)',
#  'Calapor': 'Calapor (2013)',
#  'Call Center Girl': 'Call Center Girl (2013)',
#  'Cannon Fodder': 'Cannon Fodder (2013)',
#  'Canopy': 'Canopy (2013)',
#  'Captain Phillips': 'Captain Phillips (2013)',
#  'Carrie': 'Carrie (2013)',
#  'Cavedigger': 'Cavedigger (2013)',
#  'Cavemen': 'Cavemen (2013)',
#  'Celal ile Ceren': 'Celal ile Ceren (2013)',
#  'Celluloid': 'Celluloid (2013)',
#  'Chander Pahar': 'Chander Pahar (2013)',
#  'Chandra': 'Chandra (2013)',
#  "Charlie's Country": "Charlie's Country (2013)",
#  'Chashme Baddoor': 'Chashme Baddoor (2013)',
#  'Chastity Bites': 'Chastity Bites (2013)',
#  "Cheatin'": "Cheatin' (2013)",
#  "Cheech & Chong's Animated Movie": "Cheech & Chong's Animated Movie (2013)",
#  'Chennai Express': 'Chennai Express (2013)',
#  'Chennaiyil Oru Naal': 'Chennaiyil Oru Naal (2013)',
#  'Child of God': 'Child of God (2013)',
#  'Clark: A Gonzomentary': 'Clark: A Gonzomentary (2013)',
#  'Cloudy with a Chance of Meatballs 2': 'Cloudy with a Chance of Meatballs 2 (2013)',
#  'Coffee Town': 'Coffee Town (2013)',
#  'Coffin Baby': 'Coffin Baby (2013)',
#  'Coherence': 'Coherence (2013)',
#  'Computer Chess': 'Computer Chess (2013)',
#  'Confusion Na Wa': 'Confusion Na Wa (2013)',
#  'Contest': 'Contest (2013)',
#  'Cottage Country': 'Cottage Country (2013)',
#  'Crawlspace': 'Crawlspace (2013)',
#  'Crazy Kind of Love': 'Crazy Kind of Love (2013)',
#  'Crisis Hotline: Veterans Press 1': 'Crisis Hotline: Veterans Press 1 (2013)',
#  'Cristo Rey': 'Cristo Rey (2013)',
#  'Crocodile Love Story': 'Crocodile Love Story (2013)',
#  'Crossing Bridges': 'Crossing Bridges (2013)',
#  'Curse of Chucky': 'Curse of Chucky (2013)',
#  'Cutie and the Boxer': 'Cutie and the Boxer (2013)',
#  'D Company': 'D Company (2013)',
#  'Dallas Buyers Club': 'Dallas Buyers Club (2013)',
#  'Dark Circles': 'Dark Circles (2013)',
#  'Dark Feed': 'Dark Feed (2013)',
#  'Dark Touch': 'Dark Touch (2013)',
#  'Daughters of Dolma': 'Daughters of Dolma (2013)',
#  'Dead Man Down': 'Dead Man Down (2013)',
#  "Dealin' with Idiots": "Dealin' with Idiots (2013)",
#  'Dear Mr. Watterson': 'Dear Mr. Watterson (2013)',
#  'Deewana': 'Deewana (2013)',
#  'Dehraadun Diary': 'Dehraadun Diary (2013)',
#  'Delivery Man': 'Delivery Man (2013)',
#  'Desert Runners': 'Desert Runners (2013)',
#  'Desingu Raja': 'Desingu Raja (2013)',
#  'Despicable Me 2': 'Despicable Me 2 (2013)',
#  'Devil May Call': 'Devil May Call (2013)',
#  'Devil in My Ride': 'Devil in My Ride (2013)',
#  "Devil's Knot": "Devil's Knot (2013)",
#  'Die Tapferen Haende im Chaos der Zeit': 'Die Tapferen Haende im Chaos der Zeit (2013)',
#  'Dirty Wars': 'Dirty Wars (2013)',
#  'Don Jon': 'Don Jon (2013)',
#  "Don't Go to the Reunion": "Don't Go to the Reunion (2013)",
#  "Don't Pass Me By": "Don't Pass Me By (2013)",
#  'Drinking Buddies': 'Drinking Buddies (2013)',
#  'Drishyam': 'Drishyam (2013)',
#  'Drones': 'Drones (2013)',
#  'Duniyadari': 'Duniyadari (2013)',
#  'Eastern Boys': 'Eastern Boys (2013)',
#  'Ek Thi Daayan': 'Ek Thi Daayan (2013)',
#  'Elaine Stritch: Shoot Me': 'Elaine Stritch: Shoot Me (2013)',
#  'Election': 'Election (2013)',
#  'Elegy for a Revolutionary': 'Elegy for a Revolutionary (2013)',
#  'Empire State': 'Empire State (2013)',
#  "Ender's Game": "Ender's Game (2013)",
#  'Endrendrum Punnagai': 'Endrendrum Punnagai (2013)',
#  'Enemies Closer': 'Enemies Closer (2013)',
#  'Enemy': 'Enemy (2013)',
#  'Enough Said': 'Enough Said (2013)',
#  'Ente': 'Ente (2013)',
#  'Enter the Dangerous Mind': 'Enter the Dangerous Mind (2013)',
#  'Epic': 'Epic (2013)',
#  'Escape Plan': 'Escape Plan (2013)',
#  'Escape from Planet Earth': 'Escape from Planet Earth (2013)',
#  'Escape from Tomorrow': 'Escape from Tomorrow (2013)',
#  'Eternity': 'Eternity (2013)',
#  'Ethir Neechal': 'Ethir Neechal (2013)',
#  'Europa Report': 'Europa Report (2013)',
#  'Every Everything: The Music, Life & Times of Grant Hart': 'Every Everything: The Music, Life & Times of Grant Hart (2013)',
#  'Everyday Is Like Sunday': 'Everyday Is Like Sunday (2013)',
#  "Everyone's Going to Die": "Everyone's Going to Die (2013)",
#  'Everywhen': 'Everywhen (2013)',
#  'Evil Dead': 'Evil Dead (2013)',
#  'Exit Marrakech': 'Exit Marrakech (2013)',
#  'Facing Fear': 'Facing Fear (2013)',
#  'Fading Gigolo': 'Fading Gigolo (2013)',
#  'Fading West': 'Fading West (2013)',
#  'Fandry': 'Fandry (2013)',
#  'Fedz': 'Fedz (2013)',
#  'Felony': 'Felony (2013)',
#  'Fighting for Freedom': 'Fighting for Freedom (2013)',
#  'Filthy Gorgeous: The Bob Guccione Story': 'Filthy Gorgeous: The Bob Guccione Story (2013)',
#  'Finding Neighbors': 'Finding Neighbors (2013)',
#  'Finding Vivian Maier': 'Finding Vivian Maier (2013)',
#  'Fire in the Blood': 'Fire in the Blood (2013)',
#  'Fire in the Night': 'Fire in the Night (2013)',
#  'Five Dances': 'Five Dances (2013)',
#  'Forbidden Ground': 'Forbidden Ground (2013)',
#  'Force of Execution': 'Force of Execution (2013)',
#  'Forget Us Not': 'Forget Us Not (2013)',
#  'Four Assassins': 'Four Assassins (2013)',
#  'Four Corners': 'Four Corners (2013)',
#  'FrackNation': 'FrackNation (2013)',
#  'Fractured': 'Fractured (2013)',
#  "Frankenstein's Army": "Frankenstein's Army (2013)",
#  'Free Birds': 'Free Birds (2013)',
#  'Fruitvale Station': 'Fruitvale Station (2013)',
#  'Fukrey': 'Fukrey (2013)',
#  'G.B.F.': 'G.B.F. (2013)',
#  'G.I. Joe: Retaliation': 'G.I. Joe: Retaliation (2013)',
#  'Ganesh Talkies': 'Ganesh Talkies (2013)',
#  'Gangster Squad': 'Gangster Squad (2013)',
#  'Generation Iron': 'Generation Iron (2013)',
#  'Geography Club': 'Geography Club (2013)',
#  'Gerontophilia': 'Gerontophilia (2013)',
#  'Getaway': 'Getaway (2013)',
#  'Ghadi': 'Ghadi (2013)',
#  'Ghanchakkar': 'Ghanchakkar (2013)',
#  'Ghost Team One': 'Ghost Team One (2013)',
#  'Gimme Shelter': 'Gimme Shelter (2013)',
#  'Gippi': 'Gippi (2013)',
#  'Girl on a Bicycle': 'Girl on a Bicycle (2013)',
#  'Gloria Victoria': 'Gloria Victoria (2013)',
#  'Go Goa Gone': 'Go Goa Gone (2013)',
#  'God Loves Uganda': 'God Loves Uganda (2013)',
#  'God for Sale': 'God for Sale (2013)',
#  'Goodbye World': 'Goodbye World (2013)',
#  'Googly': 'Googly (2013)',
#  'Gori Tere Pyaar Mein': 'Gori Tere Pyaar Mein (2013)',
#  'Goynar Baksho': 'Goynar Baksho (2013)',
#  'Grace Unplugged': 'Grace Unplugged (2013)',
#  'Grand Central': 'Grand Central (2013)',
#  'Gravity': 'Gravity (2013)',
#  'Grow Up, Tony Phillips': 'Grow Up, Tony Phillips (2013)',
#  'Grown Ups 2': 'Grown Ups 2 (2013)',
#  'Grudge Match': 'Grudge Match (2013)',
#  'Guest House': 'Guest House (2013)',
#  'Gunde Jaari Gallanthayyinde': 'Gunde Jaari Gallanthayyinde (2013)',
#  'Gundello Godari': 'Gundello Godari (2013)',
#  'Haani': 'Haani (2013)',
#  'Half Serious': 'Half Serious (2013)',
#  'Hammer of the Gods': 'Hammer of the Gods (2013)',
#  'Han Gong-ju': 'Han Gong-ju (2013)',
#  'Hansel & Gretel Get Baked': 'Hansel & Gretel Get Baked (2013)',
#  'Hansel & Gretel: Witch Hunters': 'Hansel & Gretel: Witch Hunters (2013)',
#  'Haridas': 'Haridas (2013)',
#  'Haunter': 'Haunter (2013)',
#  'Hawking': 'Hawking (2013)',
#  'HazMat': 'HazMat (2013)',
#  "He's Way More Famous Than You": "He's Way More Famous Than You (2013)",
#  'Head Cases: Serial Killers in the Delaware Valley': 'Head Cases: Serial Killers in the Delaware Valley (2013)',
#  'Heli': 'Heli (2013)',
#  'Her': 'Her (2013)',
#  'Hidden Universe 3D': 'Hidden Universe 3D (2013)',
#  'Himmatwala': 'Himmatwala (2013)',
#  'Hit & Stay': 'Hit & Stay (2013)',
#  'Holy Ghost People': 'Holy Ghost People (2013)',
#  'Home Run': 'Home Run (2013)',
#  'Honey Bee': 'Honey Bee (2013)',
#  'Honor Diaries': 'Honor Diaries (2013)',
#  'Horns': 'Horns (2013)',
#  'Hotell': 'Hotell (2013)',
#  'Hours': 'Hours (2013)',
#  'House of Dust': 'House of Dust (2013)',
#  'House of Good and Evil': 'House of Good and Evil (2013)',
#  'How I Live Now': 'How I Live Now (2013)',
#  'How to Lose Your Virginity': 'How to Lose Your Virginity (2013)',
#  'Hunting Elephants': 'Hunting Elephants (2013)',
#  'I Grew Up in Princeton': 'I Grew Up in Princeton (2013)',
#  'I Love You, Apple, I Love You, Orange': 'I Love You, Apple, I Love You, Orange (2013)',
#  'I Spit on Your Grave 2': 'I Spit on Your Grave 2 (2013)',
#  'I Used to Be Darker': 'I Used to Be Darker (2013)',
#  "I'll Follow You Down": "I'll Follow You Down (2013)",
#  "I'm in Love with a Church Girl": "I'm in Love with a Church Girl (2013)",
#  'Ida': 'Ida (2013)',
#  'Identity Thief': 'Identity Thief (2013)',
#  'Idharkuthane Aasaipattai Balakumara': 'Idharkuthane Aasaipattai Balakumara (2013)',
#  'Idukki Gold': 'Idukki Gold (2013)',
#  'If You Build It': 'If You Build It (2013)',
#  'Ilo Ilo': 'Ilo Ilo (2013)',
#  'Immanuel': 'Immanuel (2013)',
#  'In Bloom': 'In Bloom (2013)',
#  'In Secret': 'In Secret (2013)',
#  'In a World...': 'In a World... (2013)',
#  'In the Sands of Babylon': 'In the Sands of Babylon (2013)',
#  'Indescribable': 'Indescribable (2013)',
#  'Indie Director': 'Indie Director (2013)',
#  'Inside Llewyn Davis': 'Inside Llewyn Davis (2013)',
#  'Insidious: Chapter 2': 'Insidious: Chapter 2 (2013)',
#  'Interior. Leather Bar.': 'Interior. Leather Bar. (2013)',
#  'Ishkq in Paris': 'Ishkq in Paris (2013)',
#  'It Takes a Man and a Woman': 'It Takes a Man and a Woman (2013)',
#  'It Was You Charlie': 'It Was You Charlie (2013)',
#  'Jack the Giant Slayer': 'Jack the Giant Slayer (2013)',
#  'Jackass Presents: Bad Grandpa': 'Jackass Presents: Bad Grandpa (2013)',
#  'Jadoo': 'Jadoo (2013)',
#  'Jake Squared': 'Jake Squared (2013)',
#  'Jal': 'Jal (2013)',
#  'Jannal Oram': 'Jannal Oram (2013)',
#  'Java Heat': 'Java Heat (2013)',
#  'Jazz in Turkey': 'Jazz in Turkey (2013)',
#  'Jews of Egypt': 'Jews of Egypt (2013)',
#  'Jhola': 'Jhola (2013)',
#  'Jobs': 'Jobs (2013)',
#  'Justice Is Mind': 'Justice Is Mind (2013)',
#  'Justin and the Knights of Valour': 'Justin and the Knights of Valour (2013)',
#  'Kaal Madhumas': 'Kaal Madhumas (2013)',
#  'Kadal': 'Kadal (2013)',
#  'Kadal Kadannu Oru Maathukutty': 'Kadal Kadannu Oru Maathukutty (2013)',
#  'Kaddipudi': 'Kaddipudi (2013)',
#  'Kadhaveedu': 'Kadhaveedu (2013)',
#  'Kalyana Samayal Saadham': 'Kalyana Samayal Saadham (2013)',
#  'Kangal Malsat': 'Kangal Malsat (2013)',
#  'Kanna Laddu Thinna Aasaiya': 'Kanna Laddu Thinna Aasaiya (2013)',
#  'Kedi Billa Killadi Ranga': 'Kedi Billa Killadi Ranga (2013)',
#  'Khumba': 'Khumba (2013)',
#  'Kick-Ass 2': 'Kick-Ass 2 (2013)',
#  'Kids for Cash': 'Kids for Cash (2013)',
#  'Kill Your Darlings': 'Kill Your Darlings (2013)',
#  'Killing Season': 'Killing Season (2013)',
#  'Krrish 3': 'Krrish 3 (2013)',
#  'Ku! Kin-dza-dza': 'Ku! Kin-dza-dza (2013)',
#  'Kunjananthante Kada': 'Kunjananthante Kada (2013)',
#  'Kutti Puli': 'Kutti Puli (2013)',
#  'Kvadrat': 'Kvadrat (2013)',
#  "L'intrepido": "L'intrepido (2013)",
#  'LFO': 'LFO (2013)',
#  'Labor Day': 'Labor Day (2013)',
#  'Lake Windfall': 'Lake Windfall (2013)',
#  'Last Passenger': 'Last Passenger (2013)',
#  'Last Vegas': 'Last Vegas (2013)',
#  "Legends of Oz: Dorothy's Return": "Legends of Oz: Dorothy's Return (2013)",
#  'Let the Fire Burn': 'Let the Fire Burn (2013)',
#  'Linsanity': 'Linsanity (2013)',
#  'Little Feet': 'Little Feet (2013)',
#  'Locke': 'Locke (2013)',
#  'Lone Survivor': 'Lone Survivor (2013)',
#  'Lord of Tears': 'Lord of Tears (2013)',
#  'Lulu femme nue': 'Lulu femme nue (2013)',
#  'Maazii': 'Maazii (2013)',
#  'Machete Kills': 'Machete Kills (2013)',
#  'Made in America': 'Made in America (2013)',
#  'Madras Cafe': 'Madras Cafe (2013)',
#  'Magic Magic': 'Magic Magic (2013)',
#  'Mahabharat': 'Mahabharat (2013)',
#  'Mahapurush O Kapurush': 'Mahapurush O Kapurush (2013)',
#  'Main Hoon Shahid Afridi': 'Main Hoon Shahid Afridi (2013)',
#  'Main Krishna Hoon': 'Main Krishna Hoon (2013)',
#  'Make Your Move': 'Make Your Move (2013)',
#  'Man of Steel': 'Man of Steel (2013)',
#  'Man of Tai Chi': 'Man of Tai Chi (2013)',
#  'Mandela: Long Walk to Freedom': 'Mandela: Long Walk to Freedom (2013)',
#  'Marina': 'Marina (2013)',
#  'Mark of the Dog Rose': 'Mark of the Dog Rose (2013)',
#  'Maryan': 'Maryan (2013)',
#  'Masala': 'Masala (2013)',
#  'Matterhorn': 'Matterhorn (2013)',
#  'Max Rose': 'Max Rose (2013)',
#  'McCanick': 'McCanick (2013)',
#  'McConkey': 'McConkey (2013)',
#  'Mediastan': 'Mediastan (2013)',
#  'Meghe Dhaka Tara': 'Meghe Dhaka Tara (2013)',
#  'Mere Dad Ki Maruti': 'Mere Dad Ki Maruti (2013)',
#  'Mere Haule Dost': 'Mere Haule Dost (2013)',
#  'Metro Manila': 'Metro Manila (2013)',
#  'Mickey Virus': 'Mickey Virus (2013)',
#  'Miele': 'Miele (2013)',
#  'Mindscape': 'Mindscape (2013)',
#  'Mirage Men': 'Mirage Men (2013)',
#  'Mirchi': 'Mirchi (2013)',
#  'Mishawr Rawhoshyo': 'Mishawr Rawhoshyo (2013)',
#  'Miss You Can Do It': 'Miss You Can Do It (2013)',
#  'Missionary': 'Missionary (2013)',
#  'Mister John': 'Mister John (2013)',
#  'Money for Nothing: Inside the Federal Reserve': 'Money for Nothing: Inside the Federal Reserve (2013)',
#  'Monsoon Shootout': 'Monsoon Shootout (2013)',
#  'Monsters University': 'Monsters University (2013)',
#  'Moodar Koodam': 'Moodar Koodam (2013)',
#  'Moshi Monsters: The Movie': 'Moshi Monsters: The Movie (2013)',
#  'Movie 43': 'Movie 43 (2013)',
#  'Mr Hublot': 'Mr Hublot (2013)',
#  "Mr. Morgan's Last Love": "Mr. Morgan's Last Love (2013)",
#  'Mt. Zion': 'Mt. Zion (2013)',
#  'Murder 3': 'Murder 3 (2013)',
#  'Muscle Shoals': 'Muscle Shoals (2013)',
#  'Must Be... Love': 'Must Be... Love (2013)',
#  'My Little Bossings': 'My Little Bossings (2013)',
#  'My Prairie Home': 'My Prairie Home (2013)',
#  'My Sweet Pepper Land': 'My Sweet Pepper Land (2013)',
#  'Mystery Road': 'Mystery Road (2013)',
#  'Naa Bangaaru Talli': 'Naa Bangaaru Talli (2013)',
#  'Naan Rajavaga Pogiren': 'Naan Rajavaga Pogiren (2013)',
#  'Nadan': 'Nadan (2013)',
#  'Nailbiter': 'Nailbiter (2013)',
#  'Naiyaandi': 'Naiyaandi (2013)',
#  'Nasha': 'Nasha (2013)',
#  'Natholi Oru Cheriya Meenalla': 'Natholi Oru Cheriya Meenalla (2013)',
#  'Naveena Saraswathi Sabatham': 'Naveena Saraswathi Sabatham (2013)',
#  'Nebraska': 'Nebraska (2013)',
#  'Neelakasham Pachakadal Chuvanna Bhoomi': 'Neelakasham Pachakadal Chuvanna Bhoomi (2013)',
#  'Neram': 'Neram (2013)',
#  'Never Die Young': 'Never Die Young (2013)',
#  'Ni Jing: Thou Shalt Not Steal': 'Ni Jing: Thou Shalt Not Steal (2013)',
#  'Night Moves': 'Night Moves (2013)',
#  'Night Train to Lisbon': 'Night Train to Lisbon (2013)',
#  'Ninja: Shadow of a Tear': 'Ninja: Shadow of a Tear (2013)',
#  'No Clue': 'No Clue (2013)',
#  'No Evidence of Disease': 'No Evidence of Disease (2013)',
#  'No Joke': 'No Joke (2013)',
#  'North 24 Kaatham': 'North 24 Kaatham (2013)',
#  'Not Another Happy Ending': 'Not Another Happy Ending (2013)',
#  'O Concurso': 'O Concurso (2013)',
#  'Odd Thomas': 'Odd Thomas (2013)',
#  'Oil Sands Karaoke': 'Oil Sands Karaoke (2013)',
#  'Oldboy': 'Oldboy (2013)',
#  'Olympus Has Fallen': 'Olympus Has Fallen (2013)',
#  'Omar': 'Omar (2013)',
#  'On the Job': 'On the Job (2013)',
#  'On the Side of the Road': 'On the Side of the Road (2013)',
#  'Onaayum Aattukkuttiyum': 'Onaayum Aattukkuttiyum (2013)',
#  'Once Upon a Time in Vietnam': 'Once Upon a Time in Vietnam (2013)',
#  'One Direction: This Is Us': 'One Direction: This Is Us (2013)',
#  'One Night Surprise': 'One Night Surprise (2013)',
#  'Ongole Githa': 'Ongole Githa (2013)',
#  'Only God Forgives': 'Only God Forgives (2013)',
#  'Only Lovers Left Alive': 'Only Lovers Left Alive (2013)',
#  'Only the Young Die Good': 'Only the Young Die Good (2013)',
#  'Open Grave': 'Open Grave (2013)',
#  'Out of the Furnace': 'Out of the Furnace (2013)',
#  'Outpost: Rise of the Spetsnaz': 'Outpost: Rise of the Spetsnaz (2013)',
#  'Oxyana': 'Oxyana (2013)',
#  'Oz the Great and Powerful': 'Oz the Great and Powerful (2013)',
#  'Pacific Rim': 'Pacific Rim (2013)',
#  'Pain & Gain': 'Pain & Gain (2013)',
#  'Palo Alto': 'Palo Alto (2013)',
#  'Pandiya Naadu': 'Pandiya Naadu (2013)',
#  "Pandora's Promise": "Pandora's Promise (2013)",
#  'Papilio Buddha': 'Papilio Buddha (2013)',
#  'Paradesi': 'Paradesi (2013)',
#  'Parker': 'Parker (2013)',
#  'Parkland': 'Parkland (2013)',
#  'Pattathu Yaanai': 'Pattathu Yaanai (2013)',
#  'Penthouse North': 'Penthouse North (2013)',
#  'Percy Jackson: Sea of Monsters': 'Percy Jackson: Sea of Monsters (2013)',
#  'Phata Poster Nikhla Hero': 'Phata Poster Nikhla Hero (2013)',
#  'Philomena': 'Philomena (2013)',
#  'Phoring': 'Phoring (2013)',
#  'Pieces of Easter': 'Pieces of Easter (2013)',
#  'Pioneer': 'Pioneer (2013)',
#  'Pit Stop': 'Pit Stop (2013)',
#  'Pizza II: Villa': 'Pizza II: Villa (2013)',
#  'Planes': 'Planes (2013)',
#  'Plot for Peace': 'Plot for Peace (2013)',
#  'Plush': 'Plush (2013)',
#  'Popat': 'Popat (2013)',
#  'Potomanto': 'Potomanto (2013)',
#  'Powder Room': 'Powder Room (2013)',
#  'Prague': 'Prague (2013)',
#  'Prem Mhanje Prem Mhanje Prem Asta': 'Prem Mhanje Prem Mhanje Prem Asta (2013)',
#  'Premachi Goshta': 'Premachi Goshta (2013)',
#  'Prince Avalanche': 'Prince Avalanche (2013)',
#  'Prison Terminal: The Last Days of Private Jack Hall': 'Prison Terminal: The Last Days of Private Jack Hall (2013)',
#  'Prisoners': 'Prisoners (2013)',
#  'Prisoners of the Sun': 'Prisoners of the Sun (2013)',
#  'Priyathama Neevachata Kushalama': 'Priyathama Neevachata Kushalama (2013)',
#  'Project Censored the Movie': 'Project Censored the Movie (2013)',
#  'Proloy': 'Proloy (2013)',
#  'R.I.P.D.': 'R.I.P.D. (2013)',
#  'R100': 'R100 (2013)',
#  'Raanjhanaa': 'Raanjhanaa (2013)',
#  'Raja Huli': 'Raja Huli (2013)',
#  'Raja Rani': 'Raja Rani (2013)',
#  'Rajdhani Express': 'Rajdhani Express (2013)',
#  'Rapture-Palooza': 'Rapture-Palooza (2013)',
#  'Real Playing Game': 'Real Playing Game (2013)',
#  'Red Ant Dream': 'Red Ant Dream (2013)',
#  'Red Cloud: Deliverance': 'Red Cloud: Deliverance (2013)',
#  'Red Obsession': 'Red Obsession (2013)',
#  'Redwood Highway': 'Redwood Highway (2013)',
#  "Return to Nim's Island": "Return to Nim's Island (2013)",
#  'Rewind This!': 'Rewind This! (2013)',
#  'Rhymes for Young Ghouls': 'Rhymes for Young Ghouls (2013)',
#  'Richard the Lionheart': 'Richard the Lionheart (2013)',
#  'Riddick': 'Riddick (2013)',
#  'Rise of the Zombie': 'Rise of the Zombie (2013)',
#  'Robosapien: Rebooted': 'Robosapien: Rebooted (2013)',
#  "Rock and Roll's Greatest Failure: Otway the Movie": "Rock and Roll's Greatest Failure: Otway the Movie (2013)",
#  'Rocky': 'Rocky (2013)',
#  'Run & Jump': 'Run & Jump (2013)',
#  'Runner Runner': 'Runner Runner (2013)',
#  'Running from Crazy': 'Running from Crazy (2013)',
#  'Saadi Love Story': 'Saadi Love Story (2013)',
#  'Sacro GRA': 'Sacro GRA (2013)',
#  'Sadako 3D 2': 'Sadako 3D 2 (2013)',
#  'Sadda Haq': 'Sadda Haq (2013)',
#  'Sadik 2': 'Sadik 2 (2013)',
#  'Sake-Bomb': 'Sake-Bomb (2013)',
#  'Samanala Sandhawaniya': 'Samanala Sandhawaniya (2013)',
#  'Samar': 'Samar (2013)',
#  'Sand Wars': 'Sand Wars (2013)',
#  'Satya 2': 'Satya 2 (2013)',
#  'Satyanweshi': 'Satyanweshi (2013)',
#  'Savannah': 'Savannah (2013)',
#  'Saving Lincoln': 'Saving Lincoln (2013)',
#  'Saving Mr. Banks': 'Saving Mr. Banks (2013)',
#  'Scary Movie 5': 'Scary Movie 5 (2013)',
#  'Season of Miracles': 'Season of Miracles (2013)',
#  'Seduced and Abandoned': 'Seduced and Abandoned (2013)',
#  'Seethamma Vakitlo Sirimalle Chettu': 'Seethamma Vakitlo Sirimalle Chettu (2013)',
#  'Sepideh': 'Sepideh (2013)',
#  'Serra Pelada': 'Serra Pelada (2013)',
#  'Settai': 'Settai (2013)',
#  'Shored Up': 'Shored Up (2013)',
#  'Short Term 12': 'Short Term 12 (2013)',
#  'Shorts': 'Shorts (2013)',
#  'Shree': 'Shree (2013)',
#  'Shuddh Desi Romance': 'Shuddh Desi Romance (2013)',
#  'Siddharth': 'Siddharth (2013)',
#  'Simple Agi Ondh Love Story': 'Simple Agi Ondh Love Story (2013)',
#  'Singularity Principle': 'Singularity Principle (2013)',
#  'Skum Rocks!': 'Skum Rocks! (2013)',
#  'Snowpiercer': 'Snowpiercer (2013)',
#  'Sole Survivor': 'Sole Survivor (2013)',
#  'Solo': 'Solo (2013)',
#  'Some Velvet Morning': 'Some Velvet Morning (2013)',
#  'Something Necessary': 'Something Necessary (2013)',
#  'Sona Spa': 'Sona Spa (2013)',
#  'Sonno Profondo': 'Sonno Profondo (2013)',
#  'Soodhu Kavvum': 'Soodhu Kavvum (2013)',
#  'Sound City': 'Sound City (2013)',
#  'Stalingrad': 'Stalingrad (2013)',
#  'Stand Clear of the Closing Doors': 'Stand Clear of the Closing Doors (2013)',
#  'Star Trek Into Darkness': 'Star Trek Into Darkness (2013)',
#  'Starred Up': 'Starred Up (2013)',
#  'Stoker': 'Stoker (2013)',
#  'Stop the Pounding Heart': 'Stop the Pounding Heart (2013)',
#  'Subconscious Password': 'Subconscious Password (2013)',
#  'Suddenly': 'Suddenly (2013)',
#  'Summer in February': 'Summer in February (2013)',
#  'Sunlight Jr.': 'Sunlight Jr. (2013)',
#  'Sunshine on Leith': 'Sunshine on Leith (2013)',
#  'Supermensch: The Legend of Shep Gordon': 'Supermensch: The Legend of Shep Gordon (2013)',
#  'Sutta Kadhai': 'Sutta Kadhai (2013)',
#  'Svengali': 'Svengali (2013)',
#  'Swamy Ra Ra': 'Swamy Ra Ra (2013)',
#  'Sweetwater': 'Sweetwater (2013)',
#  'Tadakha': 'Tadakha (2013)',
#  'Targeting Iran': 'Targeting Iran (2013)',
#  'Terms and Conditions May Apply': 'Terms and Conditions May Apply (2013)',
#  'Texas Chainsaw 3D': 'Texas Chainsaw 3D (2013)',
#  'Thalaivaa': 'Thalaivaa (2013)',
#  'The A.R.K. Report': 'The A.R.K. Report (2013)',
#  'The Adventures of Sinbad': 'The Adventures of Sinbad (2013)',
#  'The Amityville Asylum': 'The Amityville Asylum (2013)',
#  'The Art of the Steal': 'The Art of the Steal (2013)',
#  'The Best Years': 'The Best Years (2013)',
#  'The Big Wedding': 'The Big Wedding (2013)',
#  'The Blackout': 'The Blackout (2013)',
#  'The Book Thief': 'The Book Thief (2013)',
#  'The Bride and the Lover': 'The Bride and the Lover (2013)',
#  'The Callback Queen': 'The Callback Queen (2013)',
#  'The Christmas Candle': 'The Christmas Candle (2013)',
#  'The Cloth': 'The Cloth (2013)',
#  'The Cold Lands': 'The Cold Lands (2013)',
#  'The Conjuring': 'The Conjuring (2013)',
#  'The Cosmonaut': 'The Cosmonaut (2013)',
#  'The Counselor': 'The Counselor (2013)',
#  'The Crash Reel': 'The Crash Reel (2013)',
#  'The Croods': 'The Croods (2013)',
#  'The Dead 2: India': 'The Dead 2: India (2013)',
#  "The Demon's Rook": "The Demon's Rook (2013)",
#  'The Den': 'The Den (2013)',
#  "The Devil's Violinist": "The Devil's Violinist (2013)",
#  'The Diary of a Slumlord': 'The Diary of a Slumlord (2013)',
#  'The Dick Knost Show': 'The Dick Knost Show (2013)',
#  'The Double': 'The Double (2013)',
#  'The East': 'The East (2013)',
#  'The English Teacher': 'The English Teacher (2013)',
#  'The Fifth Estate': 'The Fifth Estate (2013)',
#  'The Foxy Merkins': 'The Foxy Merkins (2013)',
#  'The Frankenstein Theory': 'The Frankenstein Theory (2013)',
#  'The Frozen Ground': 'The Frozen Ground (2013)',
#  'The Gambler': 'The Gambler (2013)',
#  'The Ghost Army': 'The Ghost Army (2013)',
#  'The Girl from Nagasaki': 'The Girl from Nagasaki (2013)',
#  'The Girl on the Train': 'The Girl on the Train (2013)',
#  'The Good Road': 'The Good Road (2013)',
#  'The Grand Seduction': 'The Grand Seduction (2013)',
#  'The Great Gatsby': 'The Great Gatsby (2013)',
#  'The Great Hip Hop Hoax': 'The Great Hip Hop Hoax (2013)',
#  'The Groundsman': 'The Groundsman (2013)',
#  'The Hangover Part III': 'The Hangover Part III (2013)',
#  'The Harry Hill Movie': 'The Harry Hill Movie (2013)',
#  'The Haunting in Connecticut 2: Ghosts of Georgia': 'The Haunting in Connecticut 2: Ghosts of Georgia (2013)',
#  'The Hobbit: The Desolation of Smaug': 'The Hobbit: The Desolation of Smaug (2013)',
#  'The Hospital': 'The Hospital (2013)',
#  'The Host': 'The Host (2013)',
#  'The Hot Flashes': 'The Hot Flashes (2013)',
#  'The House of Magic': 'The House of Magic (2013)',
#  'The Human Factor': 'The Human Factor (2013)',
#  'The Human Race': 'The Human Race (2013)',
#  'The Hunger Games: Catching Fire': 'The Hunger Games: Catching Fire (2013)',
#  'The Husband': 'The Husband (2013)',
#  'The Immigrant': 'The Immigrant (2013)',
#  'The Incredible Burt Wonderstone': 'The Incredible Burt Wonderstone (2013)',
#  'The Internship': 'The Internship (2013)',
#  'The Invisible Woman': 'The Invisible Woman (2013)',
#  'The Kill Team': 'The Kill Team (2013)',
#  'The Kings of Summer': 'The Kings of Summer (2013)',
#  'The Last Days on Mars': 'The Last Days on Mars (2013)',
#  'The Last Exorcism Part II': 'The Last Exorcism Part II (2013)',
#  'The Last Impresario': 'The Last Impresario (2013)',
#  'The Last Stand': 'The Last Stand (2013)',
#  'The Last of Robin Hood': 'The Last of Robin Hood (2013)',
#  'The Legend of Jimi Lazer': 'The Legend of Jimi Lazer (2013)',
#  'The Legend of the Reno Brothers': 'The Legend of the Reno Brothers (2013)',
#  'The Lifeguard': 'The Lifeguard (2013)',
#  'The Lone Ranger': 'The Lone Ranger (2013)',
#  'The Look of Love': 'The Look of Love (2013)',
#  'The Lost Behrupiya': 'The Lost Behrupiya (2013)',
#  'The Lost Medallion: The Adventures of Billy Stone': 'The Lost Medallion: The Adventures of Billy Stone (2013)',
#  'The Love Punch': 'The Love Punch (2013)',
#  'The Midnight Game': 'The Midnight Game (2013)',
#  'The Missing Scarf': 'The Missing Scarf (2013)',
#  'The Mortal Instruments: City of Bones': 'The Mortal Instruments: City of Bones (2013)',
#  'The Motivation': 'The Motivation (2013)',
#  'The Muslims Are Coming!': 'The Muslims Are Coming! (2013)',
#  'The Numbers Station': 'The Numbers Station (2013)',
#  'The Odd Way Home': 'The Odd Way Home (2013)',
#  'The Pardon': 'The Pardon (2013)',
#  'The Patrol': 'The Patrol (2013)',
#  'The Paw Project': 'The Paw Project (2013)',
#  'The Physician': 'The Physician (2013)',
#  'The Play': 'The Play (2013)',
#  'The Power of Few': 'The Power of Few (2013)',
#  'The Pretty One': 'The Pretty One (2013)',
#  'The Prisoner': 'The Prisoner (2013)',
#  'The Railway Man': 'The Railway Man (2013)',
#  'The Red Robin': 'The Red Robin (2013)',
#  'The Return to Homs': 'The Return to Homs (2013)',
#  'The Returned': 'The Returned (2013)',
#  'The Right Kind of Wrong': 'The Right Kind of Wrong (2013)',
#  'The Rocket': 'The Rocket (2013)',
#  'The Sacrament': 'The Sacrament (2013)',
#  'The Secret Life of Walter Mitty': 'The Secret Life of Walter Mitty (2013)',
#  'The Secret Village': 'The Secret Village (2013)',
#  'The Selfish Giant': 'The Selfish Giant (2013)',
#  'The Short Game': 'The Short Game (2013)',
#  'The Smurfs 2': 'The Smurfs 2 (2013)',
#  'The Spectacular Now': 'The Spectacular Now (2013)',
#  'The Starving Games': 'The Starving Games (2013)',
#  'The Stone': 'The Stone (2013)',
#  'The Stuart Hall Project': 'The Stuart Hall Project (2013)',
#  'The Swimmer': 'The Swimmer (2013)',
#  'The To Do List': 'The To Do List (2013)',
#  'The Trials of Cate McCall': 'The Trials of Cate McCall (2013)',
#  'The Unbelievers': 'The Unbelievers (2013)',
#  'The Vision of Paolo Soleri: Prophet in the Desert': 'The Vision of Paolo Soleri: Prophet in the Desert (2013)',
#  'The Way Way Back': 'The Way Way Back (2013)',
#  'The Wisdom Tree': 'The Wisdom Tree (2013)',
#  'The Wolf of Wall Street': 'The Wolf of Wall Street (2013)',
#  'The Wolverine': 'The Wolverine (2013)',
#  "The World's End": "The World's End (2013)",
#  'The Young and Prodigious T.S. Spivet': 'The Young and Prodigious T.S. Spivet (2013)',
#  'Theeya Velai Seiyyanum Kumaru': 'Theeya Velai Seiyyanum Kumaru (2013)',
#  'These Final Hours': 'These Final Hours (2013)',
#  'Thillu Mullu': 'Thillu Mullu (2013)',
#  'Third Person': 'Third Person (2013)',
#  'This Is Martin Bonner': 'This Is Martin Bonner (2013)',
#  'This Is Sanlitun': 'This Is Sanlitun (2013)',
#  'This Is the End': 'This Is the End (2013)',
#  'Thor: The Dark World': 'Thor: The Dark World (2013)',
#  'Time Please': 'Time Please (2013)',
#  'To Inflict': 'To Inflict (2013)',
#  'To Jennifer': 'To Jennifer (2013)',
#  'Tofael: The Tea Stall Boy': 'Tofael: The Tea Stall Boy (2013)',
#  'Torment': 'Torment (2013)',
#  'Torture Chamber': 'Torture Chamber (2013)',
#  'Triple Crossed': 'Triple Crossed (2013)',
#  'Tru Love': 'Tru Love (2013)',
#  'Trust Me': 'Trust Me (2013)',
#  'Truth': 'Truth (2013)',
#  'Tu Mera 22 Main Tera 22': 'Tu Mera 22 Main Tera 22 (2013)',
#  'Tuhog': 'Tuhog (2013)',
#  'Turbo': 'Turbo (2013)',
#  'Ugly': 'Ugly (2013)',
#  'Ukraine Is Not a Brothel': 'Ukraine Is Not a Brothel (2013)',
#  'Unacceptable Levels': 'Unacceptable Levels (2013)',
#  'Unstoppable': 'Unstoppable (2013)',
#  'Upstream Color': 'Upstream Color (2013)',
#  'Vanakkam Chennai': 'Vanakkam Chennai (2013)',
#  'Vathikuchi': 'Vathikuchi (2013)',
#  'Very Good Girls': 'Very Good Girls (2013)',
#  'Victor Young Perez': 'Victor Young Perez (2013)',
#  'Vidiyum Munn': 'Vidiyum Munn (2013)',
#  'Vikingdom': 'Vikingdom (2013)',
#  'Violette': 'Violette (2013)',
#  'Vishwaroopam': 'Vishwaroopam (2013)',
#  'WNUF Halloween Special': 'WNUF Halloween Special (2013)',
#  'Wake Up India': 'Wake Up India (2013)',
#  'Warm Bodies': 'Warm Bodies (2013)',
#  'Water & Power': 'Water & Power (2013)',
#  'We Are Northern Lights': 'We Are Northern Lights (2013)',
#  'We Are What We Are': 'We Are What We Are (2013)',
#  'We Ride: The Story of Snowboarding': 'We Ride: The Story of Snowboarding (2013)',
#  "We're the Millers": "We're the Millers (2013)",
#  'Web Junkie': 'Web Junkie (2013)',
#  'Welcome to the Punch': 'Welcome to the Punch (2013)',
#  'Wer': 'Wer (2013)',
#  'Whispers of Life': 'Whispers of Life (2013)',
#  'Whistle': 'Whistle (2013)',
#  'White House Down': 'White House Down (2013)',
#  'White T': 'White T (2013)',
#  'Who Killed Johnny': 'Who Killed Johnny (2013)',
#  'Willow Creek': 'Willow Creek (2013)',
#  'Winter in the Blood': 'Winter in the Blood (2013)',
#  'Words and Pictures': 'Words and Pictures (2013)',
#  'Worms': 'Worms (2013)',
#  'Wrong Cops': 'Wrong Cops (2013)',
#  'Yamla Pagla Deewana 2': 'Yamla Pagla Deewana 2 (2013)',
#  'Yeh Jawaani Hai Deewani': 'Yeh Jawaani Hai Deewani (2013)',
#  'Zanjeer': 'Zanjeer (2013)',
#  'Zinda Bhaag': 'Zinda Bhaag (2013)',
#  'Zindagi Jalebi': 'Zindagi Jalebi (2013)',
#  'Zombie Hunter': 'Zombie Hunter (2013)',
#  'Zombie Massacre': 'Zombie Massacre (2013)',
#  'Zulu': 'Zulu (2013)'}

# %% [markdown]
# ## Using dbpedia and linkedmdb

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
import re
import urllib2
from bs4 import BeautifulSoup
import httplib
import time

unused1 = """
                PREFIX dbpont: <http://dbpedia.org/ontology/>
                PREFIX dbpprop: <http://dbpedia.org/property/>
                PREFIX dbres: <http://dbpedia.org/resource/>
                PREFIX dbc: <http://dbpedia.org/resource/Category:>
                PREFIX foaf: <http://xmlns.com/foaf/0.1/>
                PREFIX dcterms: <http://purl.org/dc/terms/>
                PREFIX wdentity: <http://wikidata.org/entity/>
                PREFIX lmdb: <http://data.linkedmdb.org/resource/>
                PREFIX wd: <http://www.wikidata.org/entity/>
                PREFIX wdt: <http://www.wikidata.org/prop/direct/>
                PREFIX wikibase: <http://wikiba.se/ontology#>

                SELECT DISTINCT ?title 
                       (group_concat(distinct ?language;separator=", ") as ?languages) 
                       (group_concat(distinct ?country;separator=", ") as ?countries) 
                       # ?released
                       # ?gross
                       # ?comment
                       # ?abstract
                       (?movie as ?dbpediaLink)
                       # ?wikipediaLink
                       # ?wikidataID
                       # ?imdb
                       # ?rt
                WHERE
                {
                        # ?movie rdf:type dbpont:Film .
                        # ?movie rdfs:label ?title .
                        # ?movie rdfs:comment ?comment .
                        # ?movie dbpont:abstract ?abstract .
                        # ?movie dcterms:subject dbc:%(year)s_films . 
                        OPTIONAL { ?movie dbpprop:released ?released }
                        OPTIONAL { ?movie dbpprop:country ?country } 
                        OPTIONAL { ?movie dbpont:gross ?gross }
                        OPTIONAL { ?movie dbpprop:language ?language }
                        OPTIONAL { ?movie foaf:isPrimaryTopicOf ?wikipediaLink }
                        OPTIONAL { ?movie owl:sameAs ?wikidataID }
                        OPTIONAL { ?wikidataID wdt:P345 ?imdb } 
                        OPTIONAL { ?wikidataID wdt:P1258 ?rt }

                        FILTER (lang(?title) = 'en')
                        FILTER (lang(?abstract) = 'en')
                        FILTER (lang(?comment) = 'en')
                        FILTER regex(?wikidataID, "wikidata.org/entity")
                }
                """

movies_for_year_query = """
                PREFIX dbpont: <http://dbpedia.org/ontology/>
                PREFIX dbpprop: <http://dbpedia.org/property/>
                PREFIX dbres: <http://dbpedia.org/resource/>
                PREFIX dbc: <http://dbpedia.org/resource/Category:>
                PREFIX foaf: <http://xmlns.com/foaf/0.1/>
                PREFIX dcterms: <http://purl.org/dc/terms/>
                PREFIX wdentity: <http://wikidata.org/entity/>
                PREFIX wd: <http://www.wikidata.org/entity/>
                PREFIX wdt: <http://www.wikidata.org/prop/direct/>
                PREFIX wikibase: <http://wikiba.se/ontology#>

                SELECT DISTINCT ?title 
                       (group_concat(distinct ?language;separator=", ") as ?languages) 
                       (group_concat(distinct ?country;separator=", ") as ?countries) 
                       # ?released
                       # ?gross
                       # ?comment
                       # ?abstract
                       (?movie as ?dbpediaLink)
                       # ?wikipediaLink
                       # ?wikidataID

                WHERE
                {
                        # ?movie rdf:type dbpont:Film .
                        # ?movie rdfs:label ?title .
                        # ?movie rdfs:comment ?comment .
                        # ?movie dbpont:abstract ?abstract .
                        # ?movie dcterms:subject dbc:%(year)s_films . 
                        OPTIONAL { ?movie dbpprop:released ?released }
                        OPTIONAL { ?movie dbpprop:country ?country } 
                        OPTIONAL { ?movie dbpont:gross ?gross }
                        OPTIONAL { ?movie dbpprop:language ?language }
                        OPTIONAL { ?movie foaf:isPrimaryTopicOf ?wikipediaLink }
                        OPTIONAL { ?movie owl:sameAs ?wikidataID }

                        FILTER (lang(?title) = 'en')
                        FILTER (lang(?abstract) = 'en')
                        FILTER (lang(?comment) = 'en')
                        FILTER regex(?wikidataID, "wikidata.org/entity")
                }
                """

unused2 = """
                PREFIX dbpont: <http://dbpedia.org/ontology/>
                PREFIX dbpprop: <http://dbpedia.org/property/>
                PREFIX dbres: <http://dbpedia.org/resource/>
                PREFIX dbc: <http://dbpedia.org/resource/Category:>
                PREFIX foaf: <http://xmlns.com/foaf/0.1/>
                PREFIX dcterms: <http://purl.org/dc/terms/>
                PREFIX wdentity: <http://wikidata.org/entity/>

                SELECT DISTINCT ?title 
                       (group_concat(distinct ?language;separator=", ") as ?languages) 
                       (group_concat(distinct ?country;separator=", ") as ?countries) 
                       # ?released
                       # ?gross
                       # ?comment
                       # ?abstract
                       (?movie as ?dbpediaLink)
                       # ?wikipediaLink
                       # ?wikidataID

                WHERE
                {
                        # ?movie rdf:type dbpont:Film .
                        # ?movie rdfs:label ?title .
                        # ?movie rdfs:comment ?comment .
                        # ?movie dbpont:abstract ?abstract .
                        # ?movie dcterms:subject dbc:%(year)s_films . 
                        OPTIONAL { ?movie dbpprop:released ?released }
                        OPTIONAL { ?movie dbpprop:country ?country } 
                        OPTIONAL { ?movie dbpont:gross ?gross }
                        OPTIONAL { ?movie dbpprop:language ?language }
                        OPTIONAL { ?movie foaf:isPrimaryTopicOf ?wikipediaLink }

                        FILTER (lang(?title) = 'en')
                        FILTER (lang(?abstract) = 'en')
                        FILTER (lang(?comment) = 'en')
                }
                """


def sparql_json_to_df(results, year):
    movie_dicts = []

    for movie in results['results']['bindings']:
        title = movie['title']['value']
        languages = movie.get('languages', None)
        if(languages):
            languages = languages['value']
        countries = movie.get('countries', None)
        if(countries):
            countries = countries['value']
        released = movie.get('released', None)
        if(released):
            released = released['value']
        gross = movie.get('gross', None)
        if(gross):
            gross = gross['value']
        comment = movie.get('comment', None)
        if(comment):
            comment = comment['value']
        abstract = movie.get('abstract', None)
        if(abstract):
            abstract = abstract['value']
        dbpediaLink = movie.get('dbpediaLink', None)
        if(dbpediaLink):
            dbpediaLink = dbpediaLink['value']
        wikipediaLink = movie.get('wikipediaLink', None)
        if(wikipediaLink):
            wikipediaLink = wikipediaLink['value']

        wikidataID = movie.get('wikidataID', None)
        if(wikidataID):
            wikidataID = wikidataID['value']
            
        movie_dicts.append({'year':year,
                            'title':title,
                            'languages':languages,
                            'countries':countries,
                            'released':released,
                            'gross':gross,
                            'comment':comment,
                            'abstract':abstract,
                            'dbpediaLink':dbpediaLink,
                            'wikipediaLink':wikipediaLink,
                            'wikidataID': wikidataID})

    df = pd.DataFrame(movie_dicts, columns=['year'] + results['head']['vars'])
    return(df)

def get_dbpedia_data_for_year(year):
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    sparql.setQuery(movies_for_year_query % {'year': str(year)})
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    year_df = sparql_json_to_df(results, year)
    # Do some cleanup
    strip_url = lambda x: re.sub("http://dbpedia.org/resource/", "", x)
    year_df.languages = year_df.languages.apply(strip_url)
    year_df.languages = year_df.languages.apply(lambda x: re.sub("_language", "", x))
    year_df.countries = year_df.countries.apply(strip_url)
    # Remove (film) or (<year> film) at the end of the title
    year_df.title = year_df.title.apply(lambda x: re.sub(r"[\ ]*\((%s)?[\ ]*film\)" % str(year), "", x))
    return(year_df)

# %%
years = range(2000, 2016)

# %%
sparql = SPARQLWrapper("http://dbpedia.org/sparql")
sparql.setQuery(movies_for_year_query % {'year': str(2001)})
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

#for year in years:
#year = 2010
#dbp_df = get_dbpedia_data_for_year(year)
    #dbp_df['wiki_plot'] = dbp_df.wikipediaLink.apply(lambda link:get_wikipedia_plot(link))
    #csv_filename = "wikipedia_plots_" + str(year) + ".csv"
    #dbp_df.to_csv(csv_filename, sep='\t', encoding='utf-8')
    #print(str(len(dbp_df)), " records for the year ", str(year), "written to ", csv_filename)

# %%
def parse_url(row):
    try:
        url = dict(row)['value']
    except:
        url = None
    return url

dbp_df.wikidataID = dbp_df.wikidataID.apply(parse_url)

# %%
wdquery = """
            PREFIX wd: <http://www.wikidata.org/entity/>
            PREFIX wdt: <http://www.wikidata.org/prop/direct/>
            PREFIX wikibase: <http://wikiba.se/ontology#>

            SELECT ?imdb ?rt WHERE {
               wd:%s wdt:P345 ?imdb .
               OPTIONAL { wd:%s wdt:P1258 ?rt }
            }

            """

def get_imdb_title(wikidata_url):
    print(wikidata_url)
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    wikidata_id = wikidata_url.rsplit('/',1)[-1]
    sparql.setQuery(wdquery % (wikidata_id, wikidata_id))
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    #year_df = sparql_json_to_df(results, year)
    return results

dbp_df.wikidataID[:3].apply(get_imdb_title)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-9d677a2104c8> in <module>()
#      21     return results
#      22
# ---> 23 dbp_df.wikidataID[:3].apply(get_imdb_title)
#
# NameError: name 'dbp_df' is not defined
